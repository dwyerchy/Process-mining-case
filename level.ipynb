# %%
import pandas as pd
import pm4py as pm
import datetime as dt

# %%
data_final = pd.read_csv('final_data.csv', sep =',', encoding='utf-8')
data_final = data_final.drop(['case:concept:name', 'concept:name', 'time:timestamp', 'hour', 'month', 'year', 'dayofweek'], axis = 1)
data_final_case = data_final.drop(['Time', 'Time_end', 'Name', 'Stage', 'duration'], axis = 1).drop_duplicates()
data_final_case
# Out:
#             ID            Time_start_case              Time_end_case  \
# 0       П00001  2023-09-12 04:32:23+00:00  2023-09-14 14:32:23+00:00
# 10      П00002  2023-06-30 17:15:48+00:00  2023-07-03 03:20:48+00:00
# 20      П00003  2024-05-13 23:30:32+00:00  2024-05-14 20:33:32+00:00
# 28      П00004  2024-09-12 19:37:14+00:00  2024-09-13 07:46:14+00:00
# 36      П00005  2024-09-08 03:58:17+00:00  2024-09-09 21:58:17+00:00
# ...        ...                        ...                        ...
# 441503  П09995  2025-01-19 14:39:28+00:00  2025-01-21 08:39:28+00:00
# 441511  П09996  2023-08-24 19:22:31+00:00  2023-08-27 05:30:31+00:00
# 441523  П09997  2023-05-22 07:36:39+00:00  2023-05-23 15:36:39+00:00
# 441532  П09998  2023-09-26 23:49:53+00:00  2023-09-27 17:53:53+00:00
# 441541  П09999  2024-08-08 21:17:58+00:00  2024-08-09 15:20:58+00:00
#
#         case_duration            Channel  \
# 0            2.416667               Офис
# 10           2.420139  Электронная почта
# ...

# %% [markdown]
# #### Анализ зацикленностей по сегментам

# %%
data_01_no_g = data_final[(data_final['cycle'] == 'no') & (data_final['case_duration'] < 1.5) & (data_final['Like'] > 3 )]
data_01_no_g
# Out:
#             ID            Time_start_case              Time_end_case  \
# 20      П00003  2024-05-13 23:30:32+00:00  2024-05-14 20:33:32+00:00
# 21      П00003  2024-05-13 23:30:32+00:00  2024-05-14 20:33:32+00:00
# 22      П00003  2024-05-13 23:30:32+00:00  2024-05-14 20:33:32+00:00
# 23      П00003  2024-05-13 23:30:32+00:00  2024-05-14 20:33:32+00:00
# 24      П00003  2024-05-13 23:30:32+00:00  2024-05-14 20:33:32+00:00
# ...        ...                        ...                        ...
# 441545  П09999  2024-08-08 21:17:58+00:00  2024-08-09 15:20:58+00:00
# 441546  П09999  2024-08-08 21:17:58+00:00  2024-08-09 15:20:58+00:00
# 441547  П09999  2024-08-08 21:17:58+00:00  2024-08-09 15:20:58+00:00
# 441548  П09999  2024-08-08 21:17:58+00:00  2024-08-09 15:20:58+00:00
# 441549  П09999  2024-08-08 21:17:58+00:00  2024-08-09 15:20:58+00:00
#
#         case_duration                                              Stage  \
# ...

# %%
data_01_no_b = data_final[(data_final['cycle'] == 'no') & (data_final['case_duration'] < 1.5) & (data_final['Like'] < 4 )]
data_01_no_b
# Out:
#             ID            Time_start_case              Time_end_case  \
# 296     П00034  2023-11-30 06:04:55+00:00  2023-12-01 12:08:55+00:00
# 297     П00034  2023-11-30 06:04:55+00:00  2023-12-01 12:08:55+00:00
# 298     П00034  2023-11-30 06:04:55+00:00  2023-12-01 12:08:55+00:00
# 299     П00034  2023-11-30 06:04:55+00:00  2023-12-01 12:08:55+00:00
# 441509  П09995  2025-01-19 14:39:28+00:00  2025-01-21 08:39:28+00:00
# 441510  П09995  2025-01-19 14:39:28+00:00  2025-01-21 08:39:28+00:00
#
#         case_duration                             Stage  \
# 36               1.75             Регистрация претензии
# ...

# %%
data_12_no_b = data_final[(data_final['cycle'] == 'no') & (data_final['case_duration'] >= 1.5) & (data_final['case_duration'] < 2) & (data_final['Like'] < 4 )]
data_12_no_b
# Out:
#             ID            Time_start_case              Time_end_case  \
# 614     П00070  2023-09-04 16:55:40+00:00  2023-09-06 10:55:40+00:00
# 615     П00070  2023-09-04 16:55:40+00:00  2023-09-06 10:55:40+00:00
# 616     П00070  2023-09-04 16:55:40+00:00  2023-09-06 10:55:40+00:00
# 617     П00070  2023-09-04 16:55:40+00:00  2023-09-06 10:55:40+00:00
# 618     П00070  2023-09-04 16:55:40+00:00  2023-09-06 10:55:40+00:00
# ...        ...                        ...                        ...
# 441498  П09994  2024-02-14 13:27:00+00:00  2024-02-16 08:27:00+00:00
# 441499  П09994  2024-02-14 13:27:00+00:00  2024-02-16 08:27:00+00:00
# 441500  П09994  2024-02-14 13:27:00+00:00  2024-02-16 08:27:00+00:00
# 441501  П09994  2024-02-14 13:27:00+00:00  2024-02-16 08:27:00+00:00
# 441502  П09994  2024-02-14 13:27:00+00:00  2024-02-16 08:27:00+00:00
#
#         case_duration                             Stage  \
# 614          1.750000             Регистрация претензии
# ...

# %%
data_12_yes_g = data_final[(data_final['cycle'] != 'no') & (data_final['case_duration'] >= 1.5) & (data_final['case_duration'] < 2) & (data_final['Like'] > 3 )]
data_12_yes_g
# Out:
# Empty DataFrame
# Columns: [ID, Time_start_case, Time_end_case, case_duration, Stage, Time, Channel, Name, Type, Hit, Place, Model, Price, Like, Time_end, duration, variant, word, cycle]
# Index: []

# %%
data_12_yes_b = data_final[(data_final['cycle'] != 'no') & (data_final['case_duration'] >= 1.5) & (data_final['case_duration'] < 2) & (data_final['Like'] < 4 )]
data_12_yes_b
# Out:
#             ID            Time_start_case              Time_end_case  \
# 116     П00014  2023-03-23 15:23:24+00:00  2023-03-25 05:29:24+00:00
# 117     П00014  2023-03-23 15:23:24+00:00  2023-03-25 05:29:24+00:00
# 118     П00014  2023-03-23 15:23:24+00:00  2023-03-25 05:29:24+00:00
# 119     П00014  2023-03-23 15:23:24+00:00  2023-03-25 05:29:24+00:00
# 120     П00014  2023-03-23 15:23:24+00:00  2023-03-25 05:29:24+00:00
# ...        ...                        ...                        ...
# 441479  П09992  2024-07-19 05:33:48+00:00  2024-07-21 04:36:48+00:00
# 441480  П09992  2024-07-19 05:33:48+00:00  2024-07-21 04:36:48+00:00
# 441481  П09992  2024-07-19 05:33:48+00:00  2024-07-21 04:36:48+00:00
# 441482  П09992  2024-07-19 05:33:48+00:00  2024-07-21 04:36:48+00:00
# 441483  П09992  2024-07-19 05:33:48+00:00  2024-07-21 04:36:48+00:00
#
#         case_duration                             Stage  \
# 116          1.587500             Регистрация претензии
# ...

# %%
# 441519  П09996  2023-08-24 19:22:31+00:00  2023-08-27 05:30:31+00:00
# 441520  П09996  2023-08-24 19:22:31+00:00  2023-08-27 05:30:31+00:00
# 441521  П09996  2023-08-24 19:22:31+00:00  2023-08-27 05:30:31+00:00
# 441522  П09996  2023-08-24 19:22:31+00:00  2023-08-27 05:30:31+00:00
#
#         case_duration                             Stage  \
# 0            2.416667             Регистрация претензии
# ...

# %%
data_23_yes_g = data_final[(data_final['cycle'] != 'no') & (data_final['case_duration'] >= 2) & (data_final['case_duration'] < 3) & (data_final['Like'] > 3 )]
data_23_yes_g
# Out:
# Empty DataFrame
# Columns: [ID, Time_start_case, Time_end_case, case_duration, Stage, Time, Channel, Name, Type, Hit, Place, Model, Price, Like, Time_end, duration, variant, word, cycle]
# Index: []

# %%
data_30_no_g = data_final[(data_final['cycle'] == 'no') & (data_final['case_duration'] >= 3) & (data_final['Like'] > 3 )]
data_30_no_g
# Out:
# Empty DataFrame
# Columns: [ID, Time_start_case, Time_end_case, case_duration, Stage, Time, Channel, Name, Type, Hit, Place, Model, Price, Like, Time_end, duration, variant, word, cycle]
# Index: []

# %%
data_30_no_b = data_final[(data_final['cycle'] == 'no') & (data_final['case_duration'] >= 3) & (data_final['Like'] < 4)]
data_30_no_b
# Out:
# Empty DataFrame
# Columns: [ID, Time_start_case, Time_end_case, case_duration, Stage, Time, Channel, Name, Type, Hit, Place, Model, Price, Like, Time_end, duration, variant, word, cycle]
# Index: []

# %%
data_30_yes_b = data_final[(data_final['cycle'] != 'no') & (data_final['case_duration'] >= 3) & (data_final['Like'] < 4)]
data_30_yes_b
# Out:
#             ID            Time_start_case              Time_end_case  \
# 1007    П00116  2023-08-22 07:39:35+00:00  2023-08-26 12:39:35+00:00
# 1008    П00116  2023-08-22 07:39:35+00:00  2023-08-26 12:39:35+00:00
# 1009    П00116  2023-08-22 07:39:35+00:00  2023-08-26 12:39:35+00:00
# 1010    П00116  2023-08-22 07:39:35+00:00  2023-08-26 12:39:35+00:00
# 1011    П00116  2023-08-22 07:39:35+00:00  2023-08-26 12:39:35+00:00
# ...        ...                        ...                        ...
# 441459  П09990  2023-04-29 16:36:02+00:00  2023-05-02 20:41:02+00:00
# 441460  П09990  2023-04-29 16:36:02+00:00  2023-05-02 20:41:02+00:00
# 441461  П09990  2023-04-29 16:36:02+00:00  2023-05-02 20:41:02+00:00
# 441462  П09990  2023-04-29 16:36:02+00:00  2023-05-02 20:41:02+00:00
# 441463  П09990  2023-04-29 16:36:02+00:00  2023-05-02 20:41:02+00:00
#
#         case_duration                             Stage  \
# 1007         4.208333             Регистрация претензии
# ...

# %%
data_30_yes_g = data_final[(data_final['cycle'] != 'no') & (data_final['case_duration'] >= 3) & (data_final['Like'] > 3)]
data_30_yes_g
# Out:
# Empty DataFrame
# Columns: [ID, Time_start_case, Time_end_case, case_duration, Stage, Time, Channel, Name, Type, Hit, Place, Model, Price, Like, Time_end, duration, variant, word, cycle]
# Index: []

# %%
like_cycle = data_final_case.groupby(['Like','cycle'])['case_duration'].mean()
like_cycle
# Out:
# Like  cycle
# 1     no                     1.149228
#       В себя: многократно    2.852939
#       В себя: разово         1.757042
#       Возврат                1.496876
#       Пинг-Понг              1.836066
# 2     no                     1.155874
#       В себя: многократно    2.847776
#       В себя: разово         1.783253
#       Возврат                1.464864
#       Пинг-Понг              1.827139
# 3     no                     1.153645
#       В себя: многократно    2.819339
#       В себя: разово         1.759455
#       Возврат                1.493299
#       Пинг-Понг              1.844856
# 4     no                     1.222423
# 5     no                     1.224055
# Name: case_duration, dtype: float64

# %%
work_data = data_23_yes_b.groupby(['cycle', 'word']).count()
work_data
# Out:
#                                      ID  Time_start_case  Time_end_case  \
# cycle               word
# В себя: многократно ABJDDDDEFGHI   7944             7944           7944
# В себя: разово      ABJDDEFGHI    19260            19260          19260
# Возврат             ABCBDEFGHI     5250             5250           5250
# Пинг-Понг           ABCBCBDEFGHI   7944             7944           7944
#
#                                   case_duration  Stage   Time  Channel   Name  \
# cycle               word
# В себя: многократно ABJDDDDEFGHI           7944   7944   7944     7944   7944
# В себя: разово      ABJDDEFGHI            19260  19260  19260    19260  19260
# Возврат             ABCBDEFGHI             5250   5250   5250     5250   5250
# Пинг-Понг           ABCBCBDEFGHI           7944   7944   7944     7944   7944
#
#                                    Type    Hit  Place  Model  Price   Like  \
# cycle               word
# ...

# %%
ping_pong = data_23_yes_b[data_23_yes_b['cycle'] == 'Пинг-Понг']
ping_pong_case = data_final_case[(data_final_case['cycle'] == 'Пинг-Понг') & (data_final_case['case_duration'] >= 2) & (data_final_case['case_duration'] < 3) & (data_final_case['Like'] < 4 )]
ping_pong.to_csv('ping_pong.csv', index=False, encoding='utf-8')
ping_pong_case.to_csv('ping_pong_case.csv', index=False, encoding='utf-8')
ping_pong_case
# Out:
#             ID            Time_start_case              Time_end_case  \
# 195     П00023  2023-10-14 23:40:30+00:00  2023-10-16 23:40:30+00:00
# 1407    П00160  2023-05-25 19:53:38+00:00  2023-05-28 02:57:38+00:00
# 1539    П00174  2024-08-04 02:29:33+00:00  2024-08-06 04:32:33+00:00
# 1776    П00201  2023-11-19 05:21:20+00:00  2023-11-21 08:28:20+00:00
# 2222    П00252  2023-05-12 05:46:18+00:00  2023-05-14 20:46:18+00:00
# ...        ...                        ...                        ...
# 439576  П09777  2024-03-11 15:31:59+00:00  2024-03-13 19:31:59+00:00
# 439865  П09810  2024-02-14 01:52:59+00:00  2024-02-16 12:57:59+00:00
# 440355  П09865  2024-11-22 13:43:57+00:00  2024-11-25 03:43:57+00:00
# 440984  П09936  2023-03-19 20:15:22+00:00  2023-03-21 23:20:22+00:00
# 441236  П09965  2023-04-27 05:12:19+00:00  2023-04-29 07:17:19+00:00
#
#         case_duration            Channel  \
# 195          2.000000               Сайт
# 1407         2.294444               Сайт
# ...

# %%
return_in = data_23_yes_b[data_23_yes_b['cycle'] == 'Возврат в себя']
return_in_case = data_final_case[(data_final_case['cycle'] == 'Возврат в себя') & (data_final_case['case_duration'] >= 2) & (data_final_case['case_duration'] < 3) & (data_final_case['Like'] < 4 )]
return_in.to_csv('return_in.csv', index=False, encoding='utf-8')
return_in_case.to_csv('return_in_case.csv', index=False, encoding='utf-8')
return_in_case
# Out:
# Empty DataFrame
# Columns: [ID, Time_start_case, Time_end_case, case_duration, Channel, Type, Hit, Place, Model, Price, Like, variant, word, cycle]
# Index: []

# %%
return_2 = data_23_yes_b[data_23_yes_b['cycle'] == 'Возврат']
return_2_case = data_final_case[(data_final_case['cycle'] == 'Возврат') & (data_final_case['case_duration'] >= 2) & (data_final_case['case_duration'] < 3) & (data_final_case['Like'] < 4 )]
return_2.to_csv('return_2.csv', index=False, encoding='utf-8')
return_2_case.to_csv('return_2_case.csv', index=False, encoding='utf-8')
return_2_case
# Out:
#             ID            Time_start_case              Time_end_case  \
# 0       П00001  2023-09-12 04:32:23+00:00  2023-09-14 14:32:23+00:00
# 1467    П00166  2024-03-22 08:42:38+00:00  2024-03-24 11:44:38+00:00
# 2899    П00330  2024-03-31 16:38:48+00:00  2024-04-02 22:38:48+00:00
# 2970    П00338  2024-03-26 06:11:19+00:00  2024-03-28 06:11:19+00:00
# 4081    П00464  2024-06-16 19:44:16+00:00  2024-06-19 01:44:16+00:00
# ...        ...                        ...                        ...
# 431305  П08845  2023-02-05 13:37:32+00:00  2023-02-07 16:37:32+00:00
# 431511  П08869  2023-02-17 02:54:59+00:00  2023-02-19 07:58:59+00:00
# 435573  П09325  2024-02-10 00:05:16+00:00  2024-02-12 05:05:16+00:00
# 437050  П09493  2023-10-09 18:39:55+00:00  2023-10-11 22:44:55+00:00
# 439088  П09721  2024-10-12 16:38:29+00:00  2024-10-14 20:43:29+00:00
#
#         case_duration            Channel  \
# 0            2.416667               Офис
# 1467         2.126389               Сайт
# ...

# %%
return_4 = data_23_yes_b[data_23_yes_b['cycle'] == 'В произвольный этап']
return_4_case = data_final_case[(data_final_case['cycle'] == 'В произвольный этап') & (data_final_case['case_duration'] >= 2) & (data_final_case['case_duration'] < 3) & (data_final_case['Like'] < 4 )]
return_4.to_csv('return_4.csv', index=False, encoding='utf-8')
return_4_case.to_csv('return_4_case.csv', index=False, encoding='utf-8')
return_4_case
# Out:
# Empty DataFrame
# Columns: [ID, Time_start_case, Time_end_case, case_duration, Channel, Type, Hit, Place, Model, Price, Like, variant, word, cycle]
# Index: []

# %%
work_data = data_12_yes_b.groupby(['cycle', 'word']).count()
work_data
# Out:
#                                      ID  Time_start_case  Time_end_case  \
# cycle               word
# В себя: многократно ABJDDDDEFGHI   1716             1716           1716
# В себя: разово      ABJDDEFGHI    15760            15760          15760
# Возврат             ABCBDEFGHI    13280            13280          13280
# Пинг-Понг           ABCBCBDEFGHI   6192             6192           6192
#
#                                   case_duration  Stage   Time  Channel   Name  \
# cycle               word
# В себя: многократно ABJDDDDEFGHI           1716   1716   1716     1716   1716
# В себя: разово      ABJDDEFGHI            15760  15760  15760    15760  15760
# Возврат             ABCBDEFGHI            13280  13280  13280    13280  13280
# Пинг-Понг           ABCBCBDEFGHI           6192   6192   6192     6192   6192
#
#                                    Type    Hit  Place  Model  Price   Like  \
# cycle               word
# ...

# %%
operation_01 = data_01_yes_b.groupby(['Stage', 'cycle'])['duration'].mean()
operation_01.head(50)
# Out:
# Stage                             cycle
# Закрытие страхового случая        В себя: многократно     93.442623
#                                   В себя: разово          89.571429
#                                   Возврат                 89.596083
#                                   Пинг-Понг               90.234987
# Обзор произошедшего случая        В себя: многократно      0.000000
#                                   В себя: разово           0.000000
#                                   Возврат                  0.000000
#                                   Пинг-Понг                0.000000
# Подготовка итоговой документации  В себя: многократно     84.590164
#                                   В себя: разово          89.220779
#                                   Возврат                 88.237454
#                                   Пинг-Понг               87.571802
# Поиск потерянной документации     Возврат                 89.449204
# ...

# %%
operation_12 = data_12_yes_b.groupby(['Stage', 'cycle'])['duration'].mean()
operation_12.head(50)
# Out:
# Stage                             cycle
# Закрытие страхового случая        В себя: многократно      91.468531
#                                   В себя: разово           90.228426
#                                   Возврат                  90.768072
#                                   Пинг-Понг                90.930233
# Обзор произошедшего случая        В себя: многократно       0.000000
#                                   В себя: разово            0.000000
#                                   Возврат                   0.000000
#                                   Пинг-Понг                 0.000000
# Подготовка итоговой документации  В себя: многократно      91.888112
#                                   В себя: разово           89.352792
#                                   Возврат                  88.599398
#                                   Пинг-Понг                88.953488
# Поиск потерянной документации     Возврат                  90.768072
# ...

# %%
operation_23 = data_23_yes_b.groupby(['Stage', 'cycle'])['duration'].mean()
operation_23.head(50)
# Out:
# Stage                             cycle
# Закрытие страхового случая        В себя: многократно      90.634441
#                                   В себя: разово           91.682243
#                                   Возврат                  92.800000
#                                   Пинг-Понг                90.634441
# Обзор произошедшего случая        В себя: многократно       0.000000
#                                   В себя: разово            0.000000
#                                   Возврат                   0.000000
#                                   Пинг-Понг                 0.000000
# Подготовка итоговой документации  В себя: многократно      90.634441
#                                   В себя: разово           90.685358
#                                   Возврат                  95.428571
#                                   Пинг-Понг                90.362538
# Поиск потерянной документации     Возврат                  92.457143
# ...

# %%
types = data_final_case.groupby('Type')['ID'].count()
types
# Out:
# Type
# Личный ущерб                             35919
# Ответственность перед третьими лицами    13954
# Name: ID, dtype: int64

# %%
channel = data_final_case.groupby('Channel')['ID'].count()
channel
# Out:
# Channel
# Офис                 14932
# Сайт                 31424
# Телефон               1025
# Электронная почта     2492
# Name: ID, dtype: int64

# %%
data_cycle_4 = data_final[(data_final['cycle'] == 'В себя: разово') & (data_final['Stage'] == 'Урегулирование претензии')]
data_cycle_min = data_cycle_4.groupby('ID')['Time'].max().reset_index()
data_cycle_min = pd.merge(data_cycle_min, data_cycle_4, how ='left')
data_cycle_min
# Out:
#           ID                       Time            Time_start_case  \
# 0     П00002  2023-07-01 23:20:48+00:00  2023-06-30 17:15:48+00:00
# 1     П00012  2024-09-24 06:48:12+00:00  2024-09-23 03:45:12+00:00
# 2     П00026  2023-08-20 15:22:27+00:00  2023-08-20 00:18:27+00:00
# 3     П00029  2023-06-12 03:31:08+00:00  2023-06-11 19:22:08+00:00
# 4     П00035  2023-06-22 10:04:32+00:00  2023-06-22 01:57:32+00:00
# ...      ...                        ...                        ...
# 5039  П09957  2023-06-10 15:51:33+00:00  2023-06-09 05:51:33+00:00
# 5040  П09963  2023-11-17 12:18:30+00:00  2023-11-17 07:12:30+00:00
# 5041  П09973  2024-09-06 10:30:01+00:00  2024-09-05 16:27:01+00:00
# 5042  П09982  2023-07-17 10:27:20+00:00  2023-07-15 22:27:20+00:00
# 5043  П09993  2024-10-22 19:11:06+00:00  2024-10-21 04:11:06+00:00
#
#                   Time_end_case  case_duration                     Stage  \
# 0     2023-07-03 03:20:48+00:00       2.420139  Урегулирование претензии
# ...

# %% [markdown]
# #### Качество работы с зацикленностями сотрудников

# %%
top_cadr = data_cycle_min.groupby('Name')['Time'].count().reset_index()
all_cadr = data_cycle_4.groupby('Name')['Time'].count().reset_index()
cadr = pd.merge(top_cadr, all_cadr, on = 'Name', suffixes=['_top', '_all'])
cadr['result'] = cadr['Time_top']/cadr['Time_all']
cadr = cadr.sort_values('result')
cadr
# Out:
#                    Name  Time_top  Time_all    result
# 10      Михаил Трофимов       124       263  0.471483
# 12      Семён Афанасьев       338       697  0.484935
# 5        Денис Прохоров       544      1117  0.487019
# 6   Елизавета Нестерова       206       420  0.490476
# 2          Анна Егорова       770      1565  0.492013
# 14         Сидоров Илья       370       737  0.502035
# 0       Алексей Лопухин       402       799  0.503129
# 4      Геннадий Кривцов       304       604  0.503311
# 13        Сергей Петров       465       922  0.504338
# 3     Владимир Воробьёв       156       309  0.504854
# 1         Алёна Волкова       203       401  0.506234
# 7         Инна Смирнова       346       682  0.507331
# 9        Леонид Куликов       594      1159  0.512511
# 8        Ксения Петрова       169       318  0.531447
# 11      Николай Кабанов        53        95  0.557895

# %%
data_pp = data_final[(data_final['cycle'] == 'Пинг-Понг') & (data_final['Stage'] == 'Регистрация претензии')]
#data_cycle_min = data_cycle_4.groupby('ID')['Time'].max().reset_index()
#data_cycle_min = pd.merge(data_cycle_min, data_cycle_4, how ='left')
#data_cycle_min
top_cadr_pp = data_pp.groupby('Name')['Time'].count().reset_index()
top_cadr_pp
# Out:
#                    Name  Time
# 0       Алексей Лопухин   101
# 1         Алёна Волкова    51
# 2          Анна Егорова   243
# 3     Владимир Воробьёв    45
# 4      Геннадий Кривцов    82
# 5        Денис Прохоров   172
# 6   Елизавета Нестерова    66
# 7         Инна Смирнова    93
# 8        Ксения Петрова    60
# 9        Леонид Куликов   200
# 10      Михаил Трофимов    37
# 11      Николай Кабанов    13
# 12      Семён Афанасьев   104
# 13        Сергей Петров   169
# 14         Сидоров Илья   125

# %%
data_ppp = data_final[(data_final['cycle'] == 'Пинг-Понг') & (data_final['Stage'] == 'Поиск потерянной документации')]
data_ppp_min = data_ppp.groupby('ID')['Time'].min().reset_index()
data_buf = data_final[['ID','Time','Name']]
data_p = pd.merge(data_ppp_min, data_buf, on = ['ID', "Time"])
bad_search = data_p.groupby('Name')['ID'].count().reset_index().rename(columns={'ID':'Bad_search'})
data_search = data_final[data_final['Stage'] == 'Поиск потерянной документации']
all_search = data_search.groupby('Name')['Stage'].count().reset_index().rename(columns={'Stage':'All_search'})
cadr_search = pd.merge(bad_search, all_search, on = 'Name')
cadr_search['Part: bad/all'] = cadr_search['Bad_search']*100/cadr_search['All_search']
cadr_search = cadr_search.sort_values('Part: bad/all', ascending=True)
cadr_search
# Out:
#                    Name  Bad_search  All_search  Part: bad/all
# 11      Николай Кабанов           8          48      16.666667
# 8        Ксения Петрова          45         222      20.270270
# 4      Геннадий Кривцов          78         377      20.689655
# 1         Алёна Волкова          56         268      20.895522
# 6   Елизавета Нестерова          60         275      21.818182
# 3     Владимир Воробьёв          45         205      21.951220
# 13        Сергей Петров         135         604      22.350993
# 7         Инна Смирнова          97         431      22.505800
# 0       Алексей Лопухин         122         526      23.193916
# 9        Леонид Куликов         184         765      24.052288
# 10      Михаил Трофимов          45         187      24.064171
# 2          Анна Егорова         240         968      24.793388
# 5        Денис Прохоров         197         790      24.936709
# 12      Семён Афанасьев         110         420      26.190476
# ...

# %%
data_ppp_max = data_ppp.groupby('ID')['Time'].max().reset_index()
data_ppp_max = data_ppp_max.rename(columns={'Time': 'Time_max'})
data_ppp_min = pd.merge(data_ppp_min, data_buf, how ='left')
data_ppp_max = pd.merge(data_ppp_max, data_buf, how ='left')

data_ppp_min
# Out:
#           ID                       Time                 Name
# 0     П00018  2023-09-03 07:24:00+00:00     Геннадий Кривцов
# 1     П00023  2023-10-15 10:40:30+00:00       Денис Прохоров
# 2     П00041  2024-02-19 22:40:35+00:00        Инна Смирнова
# 3     П00093  2024-02-15 17:08:18+00:00  Елизавета Нестерова
# 4     П00133  2024-12-24 20:34:50+00:00      Семён Афанасьев
# ...      ...                        ...                  ...
# 1556  П09810  2024-02-14 11:57:59+00:00         Анна Егорова
# 1557  П09865  2024-11-23 05:43:57+00:00         Анна Егорова
# 1558  П09935  2024-02-22 23:00:12+00:00       Леонид Куликов
# 1559  П09936  2023-03-20 02:18:22+00:00      Николай Кабанов
# 1560  П09965  2023-04-27 09:17:19+00:00      Семён Афанасьев
#
# [1561 rows x 3 columns]

# %%
ppp_min = data_ppp_min.groupby('Name')['ID'].count().reset_index()
ppp_min
# Out:
#                    Name   ID
# 0       Алексей Лопухин  122
# 1         Алёна Волкова   56
# 2          Анна Егорова  240
# 3     Владимир Воробьёв   45
# 4      Геннадий Кривцов   78
# 5        Денис Прохоров  197
# 6   Елизавета Нестерова   60
# 7         Инна Смирнова   97
# 8        Ксения Петрова   45
# 9        Леонид Куликов  184
# 10      Михаил Трофимов   45
# 11      Николай Кабанов    8
# 12      Семён Афанасьев  110
# 13        Сергей Петров  135
# 14         Сидоров Илья  139

# %%
ppp_max = data_ppp_max.groupby('Name')['ID'].count().reset_index()
ppp_max
# Out:
#                    Name    ID
# 0       Алексей Лопухин  1404
# 1         Алёна Волкова   714
# 2          Анна Егорова  2841
# 3     Владимир Воробьёв   556
# 4      Геннадий Кривцов  1055
# 5        Денис Прохоров  2158
# 6   Елизавета Нестерова   837
# 7         Инна Смирнова  1262
# 8        Ксения Петрова   659
# 9        Леонид Куликов  2204
# 10      Михаил Трофимов   502
# 11      Николай Кабанов   161
# 12      Семён Афанасьев  1236
# 13        Сергей Петров  1674
# 14         Сидоров Илья  1469
